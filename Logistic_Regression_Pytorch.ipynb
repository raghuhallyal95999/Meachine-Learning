# %%
import torch
import torch.nn as nn
import torchvision.transforms.functional as TF
from torch.autograd import Variable
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/pima-indians-diabetes.data.csv', header=None)

# %%
df.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
df.shape
# Out:
# (768, 9)

# %%
int(df.shape[0]*0.7)
# Out:
# 537

# %%
from sklearn.model_selection import train_test_split
#split the data into train and test set
train,test = train_test_split(df, test_size=0.30, random_state=0)
#save the data

# %%
df.head(542)
# Out:
#      0    1   2   3    4     5      6   7  8
# 0    6  148  72  35    0  33.6  0.627  50  1
# 1    1   85  66  29    0  26.6  0.351  31  0
# 2    8  183  64   0    0  23.3  0.672  32  1
# 3    1   89  66  23   94  28.1  0.167  21  0
# 4    0  137  40  35  168  43.1  2.288  33  1
# ..  ..  ...  ..  ..  ...   ...    ...  .. ..
# 537  0   57  60   0    0  21.7  0.735  67  0
# 538  0  127  80  37  210  36.3  0.804  23  0
# 539  3  129  92  49  155  36.4  0.968  32  1
# 540  8  100  74  40  215  39.4  0.661  43  1
# 541  3  128  72  25  190  32.4  0.549  27  1
#
# [542 rows x 9 columns]

# %%
x_train = df.iloc[0:668,0:8]
y_train = df.iloc[0:668,8]

# %%
x_test = df.iloc[668:768,0:8]
y_test = df.iloc[668:768,8]

# %%
x_train = torch.tensor(x_train.values, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.long) 
x_test = torch.tensor(x_test.values, dtype=torch.float32)
y_test = torch.tensor(y_test.values, dtype=torch.long)

# %%
x_train
# Out:
# tensor([[6.0000e+00, 1.4800e+02, 7.2000e+01,  ..., 3.3600e+01, 6.2700e-01,
#          5.0000e+01],
#         [1.0000e+00, 8.5000e+01, 6.6000e+01,  ..., 2.6600e+01, 3.5100e-01,
#          3.1000e+01],
#         [8.0000e+00, 1.8300e+02, 6.4000e+01,  ..., 2.3300e+01, 6.7200e-01,
#          3.2000e+01],
#         ...,
#         [1.0000e+00, 1.1200e+02, 8.0000e+01,  ..., 3.4800e+01, 2.1700e-01,
#          2.4000e+01],
#         [4.0000e+00, 1.4500e+02, 8.2000e+01,  ..., 3.2500e+01, 2.3500e-01,
#          7.0000e+01],
#         [1.0000e+01, 1.1100e+02, 7.0000e+01,  ..., 2.7500e+01, 1.4100e-01,
#          4.0000e+01]])

# %%
x_test
# Out:
# tensor([[6.0000e+00, 9.8000e+01, 5.8000e+01, 3.3000e+01, 1.9000e+02, 3.4000e+01,
#          4.3000e-01, 4.3000e+01],
#         [9.0000e+00, 1.5400e+02, 7.8000e+01, 3.0000e+01, 1.0000e+02, 3.0900e+01,
#          1.6400e-01, 4.5000e+01],
#         [6.0000e+00, 1.6500e+02, 6.8000e+01, 2.6000e+01, 1.6800e+02, 3.3600e+01,
#          6.3100e-01, 4.9000e+01],
#         [1.0000e+00, 9.9000e+01, 5.8000e+01, 1.0000e+01, 0.0000e+00, 2.5400e+01,
#          5.5100e-01, 2.1000e+01],
#         [1.0000e+01, 6.8000e+01, 1.0600e+02, 2.3000e+01, 4.9000e+01, 3.5500e+01,
#          2.8500e-01, 4.7000e+01],
#         [3.0000e+00, 1.2300e+02, 1.0000e+02, 3.5000e+01, 2.4000e+02, 5.7300e+01,
#          8.8000e-01, 2.2000e+01],
#         [8.0000e+00, 9.1000e+01, 8.2000e+01, 0.0000e+00, 0.0000e+00, 3.5600e+01,
#          5.8700e-01, 6.8000e+01],
#         [6.0000e+00, 1.9500e+02, 7.0000e+01, 0.0000e+00, 0.0000e+00, 3.0900e+01,
#          3.2800e-01, 3.1000e+01],
# ...

# %%
y_train = y_train.reshape(-1)

# %%
y_test = y_test.reshape(-1)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# torch.Size([668, 8])
# torch.Size([668])
# torch.Size([100, 8])
# torch.Size([100])

# %%
class LogisticRegressionModel(torch.nn.Module):
   def __init__(self, input_dim, output_dim):
     super(LogisticRegressionModel, self).__init__()
     self.linear = nn.Linear(input_dim,output_dim)
    
   def forward(self, x):
     out = self.linear(x)
     return out
   print('The Function is Good!')
# Out:
# The Function is Good!

# %%
model=LogisticRegressionModel(8,2)

# %%
criterion=torch.nn.CrossEntropyLoss()
optimizer=torch.optim.SGD(model.parameters(),lr=0.001)

# %%
number_of_epochs=1000
for epoch in range(number_of_epochs):
 y_prediction=model(x_train)
 loss=criterion(y_prediction,y_train)
 loss.backward()
 optimizer.step()
 optimizer.zero_grad()
 if (epoch+1)%10 == 0:
   print('epoch:', epoch+1,',loss=',loss.item())
# Out:
# epoch: 10 ,loss= 2.3952484130859375
# epoch: 20 ,loss= 3.719566583633423
# epoch: 30 ,loss= 3.2815234661102295
# epoch: 40 ,loss= 3.192249298095703
# epoch: 50 ,loss= 2.509077787399292
# epoch: 60 ,loss= 5.811935901641846
# epoch: 70 ,loss= 2.1245744228363037
# epoch: 80 ,loss= 5.627260208129883
# epoch: 90 ,loss= 2.011698007583618
# epoch: 100 ,loss= 5.9449286460876465
# epoch: 110 ,loss= 1.9473037719726562
# epoch: 120 ,loss= 6.139708518981934
# epoch: 130 ,loss= 1.898274302482605
# epoch: 140 ,loss= 6.267132759094238
# epoch: 150 ,loss= 1.8570775985717773
# epoch: 160 ,loss= 6.342437744140625
# epoch: 170 ,loss= 1.8174057006835938
# epoch: 180 ,loss= 6.397414684295654
# epoch: 190 ,loss= 1.780197262763977
# epoch: 200 ,loss= 6.44087553024292
# epoch: 210 ,loss= 1.7457430362701416
# epoch: 220 ,loss= 6.476036071777344
# epoch: 230 ,loss= 1.7140932083129883
# epoch: 240 ,loss= 6.504171371459961
# epoch: 250 ,loss= 1.6851086616516113
# epoch: 260 ,loss= 6.527325630187988
# ...
